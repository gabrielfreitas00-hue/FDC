# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielfreitas00-hue/FDC/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def soma(a,b):
  return a + b

def sub(a,b):
  return a - b

  a + b
